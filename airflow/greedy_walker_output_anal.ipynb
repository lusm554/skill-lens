# %%
import sys
import polars as pl
print(f"{sys.version=}")
# Out:
# sys.version='3.14.0 (main, Oct  7 2025, 09:34:52) [Clang 17.0.0 (clang-1700.3.19.1)]'

# %%
# !du -hs *.jsonl
# Out:
# 192M	vacancies_auth.jsonl
# 192M	vacancies_clean.jsonl

# %%
# %%bash
# sha256 *.jsonl
# Out:
# SHA256 (vacancies_auth.jsonl) = bba2428e39bb1a2c6b05d4ac0376a01b3727514e97a0be1b4857c9341cde46c1
# SHA256 (vacancies_clean.jsonl) = 87698c2ca991f12066e2eccb55109855a75b156da6d97076b1067f309dd0cbf9

# %%
# !head -n2 vacancies_auth.jsonl
# Out:
# {"id": "124705395", "premium": false, "name": "Консультант диагностического центра/Медицинский регистратор (Плехановская ул., 53)", "department": null, "has_test": false, "response_letter_required": false, "area": {"id": "26", "name": "Воронеж", "url": "https://api.hh.ru/areas/26"}, "salary": {"from": 35000, "to": null, "currency": "RUR", "gross": false}, "salary_range": {"from": 35000, "to": null, "currency": "RUR", "gross": false, "mode": {"id": "MONTH", "name": "За месяц"}, "frequency": null}, "type": {"id": "open", "name": "Открытая"}, "address": {"city": "Воронеж", "street": "Плехановская улица", "building": "53", "lat": 51.674226, "lng": 39.184701, "description": null, "raw": "Воронеж, Плехановская улица, 53", "metro": null, "metro_stations": [], "id": "2419688"}, "response_url": null, "sort_point_distance": null, "published_at": "2025-11-25T14:34:59+0300", "created_at": "2025-11-25T14:34:59+0300", "archived": false, "apply_alternate_url": "https://hh.ru/applicant/vacancy_respo
# ...

# %%
# %%time
df = pl.read_ndjson('vacancies_auth.jsonl')
df.info()
# Out:
# CPU times: user 168 ms, sys: 66.4 ms, total: 235 ms
# Wall time: 74.6 ms
# ---------------------------------------------------------------------------
# ComputeError                              Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', "df = pl.read_ndjson('vacancies_auth.jsonl')\ndf.info()\n")
#
# File ~/fromgit/skill-lens/historical-datasets/.venv/lib/python3.14/site-packages/IPython/core/interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#    2570 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...
